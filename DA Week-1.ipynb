# %%
# Personal Introduction Program
# Week 1 Project - Python Basics
# Author: Your Name
# Date: December 25, 2025

"""
This program collects user information and displays a personalized welcome message.
It demonstrates basic Python concepts: variables, input(), print(), and f-strings.
"""

# Print a friendly header
print("=" * 50)
print("🌟 PERSONAL INTRODUCTION PROGRAM 🌟")
print("=" * 50)
print("\nLet's get to know you better!\n")

# Collect user information using input()
name = input("What is your name? ")
age = input("How old are you? ")
hobby = input("What is your favorite hobby? ")
city = input("Which city are you from? ")
favorite_food = input("What is your favorite food? ")

# Create a personalized welcome message
print("\n" + "=" * 50)
print("🎉 WELCOME MESSAGE 🎉")
print("=" * 50)

# Display the information in a friendly format
print(f"\n🎉 Welcome {name}! 🎉")
print(f"\nHere's what we learned about you:")
print(f"  📍 You are {age} years old")
print(f"  🏙️  You live in {city}")
print(f"  🎨 You love {hobby}")
print(f"  🍕 Your favorite food is {favorite_food}")

# Add a motivational closing message
print(f"\nIt's great to meet you, {name}! Keep learning and coding! 💻✨")
print("=" * 50)

# Bonus: Create a list of all responses
user_info = [name, age, hobby, city, favorite_food]
print(f"\n📋 Summary: We collected {len(user_info)} pieces of information about you!")

# Practice with basic math operations
print("\n" + "=" * 50)
print("🧮 BONUS: Quick Math Practice")
print("=" * 50)
birth_year = 2025 - int(age)
print(f"Based on your age, you were likely born around {birth_year}!")

# Practice with lists - favorite foods
print("\n" + "=" * 50)
print("🍽️  Creating Your Favorite Foods List")
print("=" * 50)
favorite_foods = ["Pizza", "Burger", "Pasta", favorite_food]
print(f"Here are some favorite foods: {favorite_foods}")
print(f"Your favorite is: {favorite_foods[-1]}")

print("\n✅ Program completed successfully!")
print("Thank you for using the Personal Introduction Program! 🎊")
# Out:
# ...
# 🌟 PERSONAL INTRODUCTION PROGRAM 🌟
# ...
#
# Let's get to know you better!
#
# What is your name? Satyanarayana
# How old are you? 21
# What is your favorite hobby? learning
# Which city are you from? Chirala
# What is your favorite food? Chicken
#
# ...
# 🎉 WELCOME MESSAGE 🎉
# ...
#
# 🎉 Welcome Satyanarayana! 🎉
#
# Here's what we learned about you:
#   📍 You are 21 years old
#   🏙️  You live in Chirala
#   🎨 You love learning
#   🍕 Your favorite food is Chicken
#
# It's great to meet you, Satyanarayana! Keep learning and coding! 💻✨
# ...
#
# 📋 Summary: We collected 5 pieces of information about you!
#
# ...
# 🧮 BONUS: Quick Math Practice
# ...
# Based on your age, you were likely born around 2004!
#
# ...
# 🍽️  Creating Your Favorite Foods List
# ...
# Here are some favorite foods: ['Pizza', 'Burger', 'Pasta', 'Chicken ']
# Your favorite is: Chicken
#
# ✅ Program completed successfully!
# Thank you for using the Personal Introduction Program! 🎊
